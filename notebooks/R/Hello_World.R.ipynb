# %%
df <- read.csv2(file = "../_Datasources_/padaria_2016.csv")

# %%
df
# Out:
#    Mês       Pães Leite Doces Café Lanches Sopas Cervejas Vinhos Lucro
# 1  janeiro    901 129   551   1628 1190     0    447      604    59309.93
# 2  fevereiro  810 116   585   3847 1928     0    530      487    91108.20
# 3  março     1023 146   504   1767 1617     2    414      472    63102.74
# 4  abril      876 125   560   3541 2679    10    167      208    85305.83
# 5  maio       998 143   514   1734 1513    35    348      436    58078.37
# 6  junho     1204 172   435   3324 1735    56    285      344    75641.29
# 7  julho     1189 170   441   1635  891    70    131      135    48631.35
# 8  agosto    1125 161   465   2392 2210    58    244      276    75857.65
# 9  setembro   768 110   601   1174  623    20    513      689    47435.77
# 10 outubro    688  98   632   3367 1899     7    407      545    83402.97
# 11 novembro   866 124   564   2678 2249     1    371      278    71749.66
# 12 dezembro   896 128   553   3023 1908     0    506      444    81913.24

# %%
summary(df)
# Out:
#         Mês         Pães            Leite           Doces            Café
#  abril    :1   Min.   : 688.0   Min.   : 98.0   Min.   :435.0   Min.   :1174
#  agosto   :1   1st Qu.: 852.0   1st Qu.:122.0   1st Qu.:494.2   1st Qu.:1709
#  dezembro :1   Median : 898.5   Median :128.5   Median :552.0   Median :2535
#  fevereiro:1   Mean   : 945.3   Mean   :135.2   Mean   :533.8   Mean   :2509
#  janeiro  :1   3rd Qu.:1048.5   3rd Qu.:149.8   3rd Qu.:569.2   3rd Qu.:3335
#  julho    :1   Max.   :1204.0   Max.   :172.0   Max.   :632.0   Max.   :3847
#  (Other)  :6
#     Lanches         Sopas          Cervejas         Vinhos           Lucro
#  Min.   : 623   Min.   : 0.00   Min.   :131.0   Min.   :135.0   47435.77:1
#  1st Qu.:1432   1st Qu.: 0.75   1st Qu.:274.8   1st Qu.:277.5   48631.35:1
#  Median :1817   Median : 8.50   Median :389.0   Median :440.0   58078.37:1
#  Mean   :1704   Mean   :21.58   Mean   :363.6   Mean   :409.8   59309.93:1
# ...

# %%
hist(df$Sopas,col = "lightblue")
# Out:
# Plot with title “Histogram of df$Sopas”
