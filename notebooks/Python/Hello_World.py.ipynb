# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
dataframe = pd.read_csv("../_Datasources_/padaria_2016.csv", sep=";")

# %%
dataframe
# Out:
#           Mês  Pães  Leite  Doces  Café  Lanches  Sopas  Cervejas  Vinhos  \
# 0     janeiro   901    129    551  1628     1190      0       447     604
# 1   fevereiro   810    116    585  3847     1928      0       530     487
# 2       março  1023    146    504  1767     1617      2       414     472
# 3       abril   876    125    560  3541     2679     10       167     208
# 4        maio   998    143    514  1734     1513     35       348     436
# 5       junho  1204    172    435  3324     1735     56       285     344
# 6       julho  1189    170    441  1635      891     70       131     135
# 7      agosto  1125    161    465  2392     2210     58       244     276
# 8    setembro   768    110    601  1174      623     20       513     689
# 9     outubro   688     98    632  3367     1899      7       407     545
# 10   novembro   866    124    564  2678     2249      1       371     278
# 11   dezembro   896    128    553  3023     1908      0       506     444
#
# ...

# %%
c = dataframe['Café']
plt.plot(c, color='green', linestyle='dashed', marker='o',
         markerfacecolor='darkgreen', markersize=8)
